# %%
# import Pkg
# Pkg.add("CSV")
# Pkg.add("DataFrames")
# Pkg.add("Plots")
# Pkg.add("Statistics")
# Pkg.add("HypothesisTests")
# Pkg.add("Clustering")
# Out:
#    Resolving package versions...
#    Installed NearestNeighbors ─ v0.4.9
#    Installed Clustering ─────── v0.14.2
#     Updating `~/Project.toml`
#   [aaaa29a8] + Clustering v0.14.2
#     Updating `~/Manifest.toml`
#   [aaaa29a8] + Clustering v0.14.2
#   [b8a86587] + NearestNeighbors v0.4.9
# Precompiling project...
#   ✓ NearestNeighbors
#   ✓ Clustering
#   2 dependencies successfully precompiled in 6 seconds (173 already precompiled)

# %%
using DataFrames
using CSV

raw_data = "Name;Team;Position;KDA_ratio;Kills_total;Deaths_total;Assists_total;KillParticipation;CS_perminute;CS_total;MinutesPlayed;Gamesplayed;Gold_pergame;Damage_pergame;Wardsplaced_pergame
007x;BKT;Jungle;1.3;8;25;24;71.1%;3.2;547;171;6;7.62;7.87;24.17
Acorn;LGD;Top;1.7;4;10;13;60.7%;6.1;666;109;3;10.77;9.40;21.33
Albis;AHQ;Support;2.4;8;31;67;60.0%;0.9;309;358;10;7.59;4.62;47.30
Amazing;OG;Jungle;2.8;20;33;71;64.1%;3.0;1566;527;13;11.31;9.30;38.85
AmazingJ;EDG;Top;2.9;14;14;26;50.6%;7.0;1295;186;6;10.55;9.43;19.00
AN;AHQ;ADC;5.2;44;16;39;66.4%;9.2;3293;358;10;14.43;17.29;6.00
aphromoo;CLG;Support;1.9;7;27;43;75.8%;0.8;165;196;6;7.17;4.33;34.83
Arrow;KT;ADC;8.9;50;12;57;74.3%;8.7;3367;385;10;15.27;22.14;7.00
Balls;C9;Top;1.6;20;29;27;56.6%;6.0;1385;232;7;10.76;8.61;17.29
Bang;SKT;ADC;15.8;83;12;107;69.3%;8.9;4807;539;16;14.60;19.82;7.00
Bengi;SKT;Jungle;5.8;36;31;144;65.7%;2.9;1566;539;16;10.48;7.97;33.00
Bjergsen;TSM;Mid;3.5;22;16;34;87.5%;8.7;2174;250;6;15.35;24.67;15.67
brTT;PNG;ADC;3.0;23;17;28;78.5%;7.2;1559;217;6;13.17;16.28;1.83
Clearlove;EDG;Jungle;4.2;17;21;72;81.7%;3.2;931;289;9;9.91;6.51;27.33
Deft;EDG;ADC;4.9;31;16;47;71.6%;8.9;2561;289;9;12.63;18.62;8.78
Dioud;PNG;Support;3.1;4;18;51;84.6%;1.1;235;217;6;7.90;4.10;47.50
Doublelift;CLG;ADC;2.7;23;19;28;77.3%;8.8;1721;196;6;12.92;19.52;5.17
Dyrus;TSM;Top;1.8;12;18;21;51.6%;5.9;1483;250;6;12.03;10.33;28.50
Easyhoon;SKT;Mid;11.3;15;4;30;65.2%;9.5;1300;137;4;14.83;20.15;6.50
Faker;SKT;Mid;7.3;55;18;77;64.4%;8.3;3337;403;12;13.27;19.37;10.00
Febiven;FNC;Mid;5.3;51;23;71;64.9%;9.4;4064;431;12;14.76;20.59;7.08
Flame;LGD;Top;4.0;11;6;13;45.3%;6.0;703;117;3;12.60;9.80;20.33
G4;BKT;Mid;1.1;13;31;21;75.6%;6.7;1156;171;6;8.90;11.57;8.83
GODV;LGD;Mid;3.1;21;19;37;71.6%;8.6;1948;226;6;14.37;20.28;18.17
⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ 007x         BKT     Jungle          1.3            8            25     ⋯
#    2 │ Acorn        LGD     Top             1.7            4            10
#    3 │ Albis        AHQ     Support         2.4            8            31
#    4 │ Amazing      OG      Jungle          2.8           20            33
#    5 │ AmazingJ     EDG     Top             2.9           14            14     ⋯
#    6 │ AN           AHQ     ADC             5.2           44            16
#    7 │ aphromoo     CLG     Support         1.9            7            27
#    8 │ Arrow        KT      ADC             8.9           50            12
#    9 │ Balls        C9      Top             1.6           20            29     ⋯
# ...

# %%
println(lol_stats[1:10,[:Name, :Team]])
# Out:
# 10×2 DataFrame
#  Row │ Name      Team
#      │ String    String
# ─────┼──────────────────
#    1 │ 007x      BKT
#    2 │ Acorn     LGD
#    3 │ Albis     AHQ
#    4 │ Amazing   OG
#    5 │ AmazingJ  EDG
#    6 │ AN        AHQ
#    7 │ aphromoo  CLG
#    8 │ Arrow     KT
#    9 │ Balls     C9
#   10 │ Bang      SKT

# %%
names(lol_stats)
describe(lol_stats)
# Out:
# 15×7 DataFrame
#  Row │ variable             mean     min    median  max    nmissing  eltype
#      │ Symbol               Union…   Any    Union…  Any    Int64     DataType
# ─────┼────────────────────────────────────────────────────────────────────────
#    1 │ Name                          007x           xPeke         0  String
#    2 │ Team                          AHQ            iG            0  String
#    3 │ Position                      ADC            Top           0  String
#    4 │ KDA_ratio            3.81412  1.1    3.0     22.0          0  Float64
#    5 │ Kills_total          22.7882  1      16.0    83            0  Int64
#    6 │ Deaths_total         22.8118  1      21.0    56            0  Int64
#    7 │ Assists_total        55.4235  6      44.0    193           0  Int64
#    8 │ KillParticipation             45.3%          87.5%         0  String
#    9 │ CS_perminute         5.71412  0.6    6.9     9.5           0  Float64
# ...

# %%
combine(groupby(lol_stats,:Position),size)
# Out:
# 5×2 DataFrame
#  Row │ Position  x1
#      │ String    Tuple…
# ─────┼────────────────────
#    1 │ Jungle    (16, 15)
#    2 │ Top       (18, 15)
#    3 │ Support   (16, 15)
#    4 │ ADC       (18, 15)
#    5 │ Mid       (17, 15)

# %%
# CS/min of Faker
lol_stats.CS_perminute[lol_stats.Name .== "Faker"]  # . is used because we "propagate" the operator among all cells
# Out:
# 1-element Vector{Float64}:
#  8.3

# %%
using Plots

# %%
scatter(lol_stats[:,:Position], lol_stats[:,:CS_perminute], label="Average CS/min")

# %%
scatter(lol_stats[:,:Position], lol_stats[:,:Kills_total], label="Number of kills")

# %%
scatter!(lol_stats[:,:Position], lol_stats[:,:Deaths_total], label="Number of deaths")

# %%
scatter!(lol_stats[:,:Position], lol_stats[:,:Assists_total], label="Number of assists")

# %%
using HypothesisTests
# testing if ADCs and Supports have the same likelihood of amount of kills
MannWhitneyUTest(lol_stats.Kills_total[lol_stats.Position .== "Support"], lol_stats.Kills_total[lol_stats.Position .== "ADC"])
# Out:
# Approximate Mann-Whitney U test
# -------------------------------
# Population details:
#     parameter of interest:   Location parameter (pseudomedian)
#     value under h_0:         0
#     point estimate:          -21.0
#
# Test summary:
#     outcome with 95% confidence: reject h_0
#     two-sided p-value:           <1e-04
#
# Details:
#     number of observations in each group: [16, 18]
#     Mann-Whitney-U statistic:             16.0
#     rank sums:                            [152.0, 443.0]
#     adjustment for ties:                  204.0
#     normal approximation (μ, σ):          (-128.0, 28.9074)

# %%
# testing if ADCs and Midlaners have the same likelihood of amount of kills
MannWhitneyUTest(lol_stats.Kills_total[lol_stats.Position .== "Mid"], lol_stats.Kills_total[lol_stats.Position .== "ADC"])
# Out:
# Approximate Mann-Whitney U test
# -------------------------------
# Population details:
#     parameter of interest:   Location parameter (pseudomedian)
#     value under h_0:         0
#     point estimate:          -3.0
#
# Test summary:
#     outcome with 95% confidence: fail to reject h_0
#     two-sided p-value:           0.7412
#
# Details:
#     number of observations in each group: [17, 18]
#     Mann-Whitney-U statistic:             142.5
#     rank sums:                            [295.5, 334.5]
#     adjustment for ties:                  66.0
#     normal approximation (μ, σ):          (-10.5, 30.2752)

# %%
# correlation between Goal per game (target) and CS per minute
using Statistics
cor(lol_stats.Gold_pergame, lol_stats.CS_perminute)
# Out:
# 0.831174528714753

# %%
scatter(lol_stats.CS_perminute, lol_stats.Gold_pergame, title="Amount of gold gained as a function of CS/min")

# %%
# correlation between Goal per game (target) and Kills per game
using Statistics
cor(lol_stats.Gold_pergame, lol_stats.Kills_total ./ lol_stats.Gamesplayed)
# Out:
# 0.8319465583496587

# %%
scatter(lol_stats.CS_perminute, lol_stats.Kills_total ./ lol_stats.Gamesplayed, title="Amount of gold gained as a function of Kills/game")

# %%
lol_stats.KillParticipation = parse.(Float64, replace.(lol_stats.KillParticipation, "%" => ""))
# Out:
# 85-element Vector{Float64}:
#  71.1
#  60.7
#  60.0
#  64.1
#  50.6
#  66.4
#  75.8
#  74.3
#  56.6
#  69.3
#  65.7
#  87.5
#  78.5
#   ⋮
#  59.3
#  75.9
#  66.7
#  57.6
#  79.7
#  69.3
#  74.2
#  54.2
#  65.4
#  59.1
#  63.2
#  74.3

# %%
# cluster players into groups according to their statistics
using Clustering
lol_clusters = kmeans(Matrix(lol_stats[:,4:15])', 5)
# Out:
# KmeansResult{Matrix{Float64}, Float64, Int64}([5.788888888888889 3.510344827586206 … 4.870000000000001 3.35; 64.33333333333333 6.827586206896552 … 42.1 23.916666666666668; … ; 19.72111111111111 7.524482758620691 … 18.999 17.833333333333336; 12.367777777777778 35.94241379310345 … 16.279 14.850833333333334], [2, 2, 2, 3, 3, 4, 2, 4, 3, 1  …  3, 4, 5, 2, 2, 1, 2, 3, 5, 3], [17820.457765041618, 70695.99066848995, 30797.855651248537, 94401.92291952111, 18512.72707151994, 2533.070405997336, 84191.13747883477, 6596.180245999247, 2461.150399520062, 16632.724441975355  …  156614.33130351966, 258645.21008599922, 40592.64105069265, 128164.67063745542, 35072.04668228293, 117953.95937530696, 54223.17539952439, 33843.26189151965, 96397.40945069678, 12705.963295520283], [9, 29, 25, 10, 12], [9, 29, 25, 10, 12], 5.986507433179642e6, 6, true)

# %%
insertcols!(lol_stats, 16, "kmeans_cluster" => lol_clusters.assignments)
# Out:
# 85×16 DataFrame
#  Row │ Name         Team    Position  KDA_ratio  Kills_total  Deaths_total  As ⋯
#      │ String       String  String    Float64    Int64        Int64         In ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ 007x         BKT     Jungle          1.3            8            25     ⋯
#    2 │ Acorn        LGD     Top             1.7            4            10
#    3 │ Albis        AHQ     Support         2.4            8            31
#    4 │ Amazing      OG      Jungle          2.8           20            33
#    5 │ AmazingJ     EDG     Top             2.9           14            14     ⋯
#    6 │ AN           AHQ     ADC             5.2           44            16
#    7 │ aphromoo     CLG     Support         1.9            7            27
#    8 │ Arrow        KT      ADC             8.9           50            12
#    9 │ Balls        C9      Top             1.6           20            29     ⋯
# ...
